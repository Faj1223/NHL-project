# %%
import os
import sys

if os.path.join(os.path.dirname(os.getcwd()), "controller") not in sys.path:
    sys.path.append(os.path.join(os.path.dirname(os.getcwd()), "controller"))

from nhl_data_loader import NHLDataLoader

# %%
loader = NHLDataLoader()

# %%
game_id = "2017021065"

# %%
loader.load_json_file(game_id)
# Out:
# {'id': 2017021065,
#  'season': 20172018,
#  'gameType': 2,
#  'limitedScoring': False,
#  'gameDate': '2018-03-12',
#  'venue': {'default': 'Capital One Arena'},
#  'venueLocation': {'default': 'Washington'},
#  'startTimeUTC': '2018-03-12T23:00:00Z',
#  'easternUTCOffset': '-04:00',
#  'venueUTCOffset': '-04:00',
#  'tvBroadcasts': [{'id': 281,
#    'market': 'N',
#    'countryCode': 'CA',
#    'network': 'TVAS',
#    'sequenceNumber': 109},
#   {'id': 292,
#    'market': 'A',
#    'countryCode': 'CA',
#    'network': 'TSN3',
#    'sequenceNumber': 134},
#   {'id': 320,
#    'market': 'H',
#    'countryCode': 'US',
#    'network': 'NBCSWA',
#    'sequenceNumber': 357}],
#  'gameState': 'OFF',
#  'gameScheduleState': 'OK',
#  'periodDescriptor': {'number': 4,
#   'periodType': 'OT',
#   'maxRegulationPeriods': 3},
#  'awayTeam': {'id': 52,
#   'name': {'default': 'Jets'},
#   'abbrev': 'WPG',
#   'score': 2,
#   'sog': 28,
# ...

# %%
loader.load_csv_file(game_id)
# Out:
#         game_id   game_date  home_team_id  period time_in_period  event_id  \
# 0    2017021065  2018-03-12            15       1          00:00         9
# 1    2017021065  2018-03-12            15       1          00:17        51
# 2    2017021065  2018-03-12            15       1          00:31        10
# 3    2017021065  2018-03-12            15       1          01:20        11
# 4    2017021065  2018-03-12            15       1          01:26        12
# ..          ...         ...           ...     ...            ...       ...
# 292  2017021065  2018-03-12            15       4          02:39       712
# 293  2017021065  2018-03-12            15       4          03:25       713
# 294  2017021065  2018-03-12            15       4          03:27       780
# 295  2017021065  2018-03-12            15       4          03:28       781
# 296  2017021065  2018-03-12            15       4          04:11       782
#
#        event_type  is_goal shot_type  x_coord  ...  last_x_coord  \
# ...

# %%
loader.load_csv_file_only_shot_events(game_id)
# Out:
#         game_id   game_date  home_team_id  period time_in_period  event_id  \
# 7    2017021065  2018-03-12            15       1          01:51        13
# 8    2017021065  2018-03-12            15       1          01:55        14
# 11   2017021065  2018-03-12            15       1          02:04        16
# 15   2017021065  2018-03-12            15       1          02:31        17
# 16   2017021065  2018-03-12            15       1          02:39        18
# ..          ...         ...           ...     ...            ...       ...
# 286  2017021065  2018-03-12            15       4          01:35       775
# 287  2017021065  2018-03-12            15       4          01:46       776
# 289  2017021065  2018-03-12            15       4          02:14       777
# 294  2017021065  2018-03-12            15       4          03:27       780
# 296  2017021065  2018-03-12            15       4          04:11       782
#
#        event_type  is_goal shot_type  x_coord  ...  last_x_coord  \
# ...

# %%
seasons = ['2016', '2019']

# %%
loader.load_csv_files(seasons)
# Out:
#            game_id   game_date  home_team_id  period time_in_period  event_id  \
# 0       2016020473  2016-12-18             2       1          00:00        52
# 1       2016020473  2016-12-18             2       1          00:09         5
# 2       2016020473  2016-12-18             2       1          00:30         6
# 3       2016020473  2016-12-18             2       1          00:44        53
# 4       2016020473  2016-12-18             2       1          01:00         7
# ...            ...         ...           ...     ...            ...       ...
# 644670  2019020007  2019-10-03             5       3          19:09       732
# 644671  2019020007  2019-10-03             5       3          19:40       733
# 644672  2019020007  2019-10-03             5       3          19:44       764
# 644673  2019020007  2019-10-03             5       3          19:56       734
# 644674  2019020007  2019-10-03             5       3          19:57       735
#
# ...

# %%
loader.load_csv_files_only_regular_season_games(seasons)
# Out:
#            game_id   game_date  home_team_id  period time_in_period  event_id  \
# 0       2016020473  2016-12-18             2       1          00:00        52
# 1       2016020473  2016-12-18             2       1          00:09         5
# 2       2016020473  2016-12-18             2       1          00:30         6
# 3       2016020473  2016-12-18             2       1          00:44        53
# 4       2016020473  2016-12-18             2       1          01:00         7
# ...            ...         ...           ...     ...            ...       ...
# 591364  2019020007  2019-10-03             5       3          19:09       732
# 591365  2019020007  2019-10-03             5       3          19:40       733
# 591366  2019020007  2019-10-03             5       3          19:44       764
# 591367  2019020007  2019-10-03             5       3          19:56       734
# 591368  2019020007  2019-10-03             5       3          19:57       735
#
# ...

# %%
loader.load_csv_files_only_playoff_games(seasons)
# Out:
#           game_id   game_date  home_team_id  period time_in_period  event_id  \
# 0      2016030123  2017-04-17             6       1          00:00        52
# 1      2016030123  2017-04-17             6       1          00:13         5
# 2      2016030123  2017-04-17             6       1          00:22         6
# 3      2016030123  2017-04-17             6       1          00:35        53
# 4      2016030123  2017-04-17             6       1          00:41        54
# ...           ...         ...           ...     ...            ...       ...
# 53301  2019030312  2020-09-09            14       3          19:46       762
# 53302  2019030312  2020-09-09            14       3          19:48       813
# 53303  2019030312  2020-09-09            14       3          19:51       763
# 53304  2019030312  2020-09-09            14       3          19:51       814
# 53305  2019030312  2020-09-09            14       3          19:57       764
#
# ...

# %%
loader.load_csv_files_only_shot_events(seasons)
# Out:
#            game_id   game_date  home_team_id  period time_in_period  event_id  \
# 0       2016020473  2016-12-18             2       1          00:44        53
# 1       2016020473  2016-12-18             2       1          03:39        61
# 2       2016020473  2016-12-18             2       1          03:50        62
# 3       2016020473  2016-12-18             2       1          04:38        66
# 4       2016020473  2016-12-18             2       1          05:02        68
# ...            ...         ...           ...     ...            ...       ...
# 154256  2019020007  2019-10-03             5       3          17:04       725
# 154257  2019020007  2019-10-03             5       3          18:05       729
# 154258  2019020007  2019-10-03             5       3          18:47       731
# 154259  2019020007  2019-10-03             5       3          19:56       734
# 154260  2019020007  2019-10-03             5       3          19:57       735
#
# ...

# %%
loader.load_csv_files_only_regular_season_games_only_shot_events(seasons)
# Out:
#            game_id   game_date  home_team_id  period time_in_period  event_id  \
# 0       2016020473  2016-12-18             2       1          00:44        53
# 1       2016020473  2016-12-18             2       1          03:39        61
# 2       2016020473  2016-12-18             2       1          03:50        62
# 3       2016020473  2016-12-18             2       1          04:38        66
# 4       2016020473  2016-12-18             2       1          05:02        68
# ...            ...         ...           ...     ...            ...       ...
# 143453  2019020007  2019-10-03             5       3          17:04       725
# 143454  2019020007  2019-10-03             5       3          18:05       729
# 143455  2019020007  2019-10-03             5       3          18:47       731
# 143456  2019020007  2019-10-03             5       3          19:56       734
# 143457  2019020007  2019-10-03             5       3          19:57       735
#
# ...

# %%
loader.load_csv_files_only_playoff_games_only_shot_events(seasons)
# Out:
#           game_id   game_date  home_team_id  period time_in_period  event_id  \
# 0      2016030123  2017-04-17             6       1          00:41        54
# 1      2016030123  2017-04-17             6       1          01:35        57
# 2      2016030123  2017-04-17             6       1          02:42        62
# 3      2016030123  2017-04-17             6       1          03:42        65
# 4      2016030123  2017-04-17             6       1          04:51        68
# ...           ...         ...           ...     ...            ...       ...
# 10798  2019030312  2020-09-09            14       3          14:27       755
# 10799  2019030312  2020-09-09            14       3          15:26       758
# 10800  2019030312  2020-09-09            14       3          17:13       759
# 10801  2019030312  2020-09-09            14       3          19:41       761
# 10802  2019030312  2020-09-09            14       3          19:51       763
#
# ...
