# %%
import sys
import pandas as pd

# %%
sys.path.append('../controller')

# %%
from nhl_data_loader import NHLDataLoader

# %%
loader = NHLDataLoader()

# %%
df_2016 = loader.load_processed_data_seasons_game_all_events(seasons=[2016])

# %%
df_2016
# Out:
#            game_id   game_date  home_team_id  period time_in_period  event_id  \
# 0       2016020473  2016-12-18             2       1          00:00        51
# 1       2016020473  2016-12-18             2       1          00:00        52
# 2       2016020473  2016-12-18             2       1          00:09         5
# 3       2016020473  2016-12-18             2       1          00:30         6
# 4       2016020473  2016-12-18             2       1          00:44        53
# ...            ...         ...           ...     ...            ...       ...
# 413334  2016021041  2017-03-16            29       3          19:49       673
# 413335  2016021041  2017-03-16            29       3          19:57       674
# 413336  2016021041  2017-03-16            29       3          20:00       675
# 413337  2016021041  2017-03-16            29       3          20:00       605
# 413338  2016021041  2017-03-16            29       3          20:00       609
#
# ...

# %%
def add_last_event_type_column(df: pd.Dataframe) -> df: pd.Dataframe:

# %%
def add_last_event_x_coord_column(df: pd.Dataframe) -> df: pd.Dataframe:

# %%
def add_last_event_y_coord_column(df: pd.Dataframe) -> df: pd.Dataframe:

# %%
def add_time_since_last_event_column(df: pd.Dataframe) -> df: pd.Dataframe:

# %%
def add_distance_from_last_event_column(df: pd.Dataframe) -> df: pd.Dataframe:

# %%
def add_rebound_column(df: pd.Dataframe) -> df: pd.Dataframe:

# %%
def add_change_in_shot_angle_column(df: pd.Dataframe) -> df: pd.Dataframe:

# %%
def add_speed_from_previous_event_column(df: pd.Dataframe) -> df: pd.Dataframe:
