# %% [markdown]
# Solutions: IFT6758 - Project milestone 1

# %% [markdown]
# 1. Download the play-by-play data for the 2016-2017 season.

# %%
import sys
from multiprocessing.util import debug

sys.path.append('..')
from ift6758.data import NHLDataDownloader

# %%
downloader = NHLDataDownloader()

# %%
downloader.download_all_seasons_play_by_play(2016,2023)
# Out:
# Game data for 2016020001 already exists in local cache.
# Game data for 2016020002 already exists in local cache.
# Game data for 2016020003 already exists in local cache.
# Game data for 2016020004 already exists in local cache.
# Game data for 2016020005 already exists in local cache.
# Game data for 2016020006 already exists in local cache.
# Game data for 2016020007 already exists in local cache.
# Game data for 2016020008 already exists in local cache.
# Game data for 2016020009 already exists in local cache.
# Game data for 2016020010 already exists in local cache.
# Game data for 2016020011 already exists in local cache.
# Game data for 2016020012 already exists in local cache.
# Game data for 2016020013 already exists in local cache.
# Game data for 2016020014 already exists in local cache.
# Game data for 2016020015 already exists in local cache.
# Game data for 2016020016 already exists in local cache.
# Game data for 2016020017 already exists in local cache.
# Game data for 2016020018 already exists in local cache.
# Game data for 2016020019 already exists in local cache.
# Game data for 2016020020 already exists in local cache.
# Game data for 2016020021 already exists in local cache.
# Game data for 2016020022 already exists in local cache.
# Game data for 2016020023 already exists in local cache.
# Game data for 2016020024 already exists in local cache.
# Game data for 2016020025 already exists in local cache.
# Game data for 2016020026 already exists in local cache.
# Game data for 2016020027 already exists in local cache.
# Game data for 2016020028 already exists in local cache.
# Game data for 2016020029 already exists in local cache.
# Game data for 2016020030 already exists in local cache.
# Game data for 2016020031 already exists in local cache.
# Game data for 2016020032 already exists in local cache.
# Game data for 2016020033 already exists in local cache.
# Game data for 2016020034 already exists in local cache.
# Game data for 2016020035 already exists in local cache.
# Game data for 2016020036 already exists in local cache.
# Game data for 2016020037 already exists in local cache.
# Game data for 2016020038 already exists in local cache.
# Game data for 2016020039 already exists in local cache.
# Game data for 2016020040 already exists in local cache.
# Game data for 2016020041 already exists in local cache.
# Game data for 2016020042 already exists in local cache.
# Game data for 2016020043 already exists in local cache.
# Game data for 2016020044 already exists in local cache.
# Game data for 2016020045 already exists in local cache.
# Game data for 2016020046 already exists in local cache.
# Game data for 2016020047 already exists in local cache.
# Game data for 2016020048 already exists in local cache.
# Game data for 2016020049 already exists in local cache.
# Game data for 2016020050 already exists in local cache.
# Game data for 2016020051 already exists in local cache.
# Game data for 2016020052 already exists in local cache.
# Game data for 2016020053 already exists in local cache.
# Game data for 2016020054 already exists in local cache.
# Game data for 2016020055 already exists in local cache.
# Game data for 2016020056 already exists in local cache.
# Game data for 2016020057 already exists in local cache.
# Game data for 2016020058 already exists in local cache.
# Game data for 2016020059 already exists in local cache.
# Game data for 2016020060 already exists in local cache.
# Game data for 2016020061 already exists in local cache.
# Game data for 2016020062 already exists in local cache.
# Game data for 2016020063 already exists in local cache.
# Game data for 2016020064 already exists in local cache.
# Game data for 2016020065 already exists in local cache.
# Game data for 2016020066 already exists in local cache.
# Game data for 2016020067 already exists in local cache.
# Game data for 2016020068 already exists in local cache.
# Game data for 2016020069 already exists in local cache.
# Game data for 2016020070 already exists in local cache.
# Game data for 2016020071 already exists in local cache.
# Game data for 2016020072 already exists in local cache.
# Game data for 2016020073 already exists in local cache.
# Game data for 2016020074 already exists in local cache.
# Game data for 2016020075 already exists in local cache.
# Game data for 2016020076 already exists in local cache.
# Game data for 2016020077 already exists in local cache.
# Game data for 2016020078 already exists in local cache.
# Game data for 2016020079 already exists in local cache.
# Game data for 2016020080 already exists in local cache.
# Game data for 2016020081 already exists in local cache.
# Game data for 2016020082 already exists in local cache.
# Game data for 2016020083 already exists in local cache.
# Game data for 2016020084 already exists in local cache.
# Game data for 2016020085 already exists in local cache.
# Game data for 2016020086 already exists in local cache.
# Game data for 2016020087 already exists in local cache.
# Game data for 2016020088 already exists in local cache.
# Game data for 2016020089 already exists in local cache.
# Game data for 2016020090 already exists in local cache.
# Game data for 2016020091 already exists in local cache.
# Game data for 2016020092 already exists in local cache.
# Game data for 2016020093 already exists in local cache.
# Game data for 2016020094 already exists in local cache.
# Game data for 2016020095 already exists in local cache.
# Game data for 2016020096 already exists in local cache.
# Game data for 2016020097 already exists in local cache.
# Game data for 2016020098 already exists in local cache.
# Game data for 2016020099 already exists in local cache.
# Game data for 2016020100 already exists in local cache.
# Game data for 2016020101 already exists in local cache.
# Game data for 2016020102 already exists in local cache.
# Game data for 2016020103 already exists in local cache.
# Game data for 2016020104 already exists in local cache.
# Game data for 2016020105 already exists in local cache.
# Game data for 2016020106 already exists in local cache.
# Game data for 2016020107 already exists in local cache.
# Game data for 2016020108 already exists in local cache.
# Game data for 2016020109 already exists in local cache.
# Game data for 2016020110 already exists in local cache.
# Game data for 2016020111 already exists in local cache.
# Game data for 2016020112 already exists in local cache.
# Game data for 2016020113 already exists in local cache.
# Game data for 2016020114 already exists in local cache.
# Game data for 2016020115 already exists in local cache.
# Game data for 2016020116 already exists in local cache.
# Game data for 2016020117 already exists in local cache.
# Game data for 2016020118 already exists in local cache.
# Game data for 2016020119 already exists in local cache.
# Game data for 2016020120 already exists in local cache.
# Game data for 2016020121 already exists in local cache.
# Game data for 2016020122 already exists in local cache.
# Game data for 2016020123 already exists in local cache.
# Game data for 2016020124 already exists in local cache.
# Game data for 2016020125 already exists in local cache.
# Game data for 2016020126 already exists in local cache.
# Game data for 2016020127 already exists in local cache.
# Game data for 2016020128 already exists in local cache.
# Game data for 2016020129 already exists in local cache.
# Game data for 2016020130 already exists in local cache.
# Game data for 2016020131 already exists in local cache.
# Game data for 2016020132 already exists in local cache.
# Game data for 2016020133 already exists in local cache.
# Game data for 2016020134 already exists in local cache.
# Game data for 2016020135 already exists in local cache.
# Game data for 2016020136 already exists in local cache.
# Game data for 2016020137 already exists in local cache.
# Game data for 2016020138 already exists in local cache.
# Game data for 2016020139 already exists in local cache.
# Game data for 2016020140 already exists in local cache.
# Game data for 2016020141 already exists in local cache.
# Game data for 2016020142 already exists in local cache.
# Game data for 2016020143 already exists in local cache.
# Game data for 2016020144 already exists in local cache.
# Game data for 2016020145 already exists in local cache.
# Game data for 2016020146 already exists in local cache.
# Game data for 2016020147 already exists in local cache.
# Game data for 2016020148 already exists in local cache.
# Game data for 2016020149 already exists in local cache.
# Game data for 2016020150 already exists in local cache.
# Game data for 2016020151 already exists in local cache.
# Game data for 2016020152 already exists in local cache.
# Game data for 2016020153 already exists in local cache.
# Game data for 2016020154 already exists in local cache.
# Game data for 2016020155 already exists in local cache.
# Game data for 2016020156 already exists in local cache.
# Game data for 2016020157 already exists in local cache.
# Game data for 2016020158 already exists in local cache.
# Game data for 2016020159 already exists in local cache.
# Game data for 2016020160 already exists in local cache.
# Game data for 2016020161 already exists in local cache.
# Game data for 2016020162 already exists in local cache.
# Game data for 2016020163 already exists in local cache.
# Game data for 2016020164 already exists in local cache.
# Game data for 2016020165 already exists in local cache.
# Game data for 2016020166 already exists in local cache.
# Game data for 2016020167 already exists in local cache.
# Game data for 2016020168 already exists in local cache.
# Game data for 2016020169 already exists in local cache.
# Game data for 2016020170 already exists in local cache.
# Game data for 2016020171 already exists in local cache.
# Game data for 2016020172 already exists in local cache.
# Game data for 2016020173 already exists in local cache.
# Game data for 2016020174 already exists in local cache.
# Game data for 2016020175 already exists in local cache.
# Game data for 2016020176 already exists in local cache.
# Game data for 2016020177 already exists in local cache.
# Game data for 2016020178 already exists in local cache.
# Game data for 2016020179 already exists in local cache.
# Game data for 2016020180 already exists in local cache.
# Game data for 2016020181 already exists in local cache.
# Game data for 2016020182 already exists in local cache.
# Game data for 2016020183 already exists in local cache.
# Game data for 2016020184 already exists in local cache.
# Game data for 2016020185 already exists in local cache.
# Game data for 2016020186 already exists in local cache.
# Game data for 2016020187 already exists in local cache.
# Game data for 2016020188 already exists in local cache.
# Game data for 2016020189 already exists in local cache.
# Game data for 2016020190 already exists in local cache.
# Game data for 2016020191 already exists in local cache.
# Game data for 2016020192 already exists in local cache.
# Game data for 2016020193 already exists in local cache.
# Game data for 2016020194 already exists in local cache.
# Game data for 2016020195 already exists in local cache.
# Game data for 2016020196 already exists in local cache.
# Game data for 2016020197 already exists in local cache.
# Game data for 2016020198 already exists in local cache.
# Game data for 2016020199 already exists in local cache.
# Game data for 2016020200 already exists in local cache.
# Game data for 2016020201 already exists in local cache.
# Game data for 2016020202 already exists in local cache.
# Game data for 2016020203 already exists in local cache.
# Game data for 2016020204 already exists in local cache.
# Game data for 2016020205 already exists in local cache.
# Game data for 2016020206 already exists in local cache.
# Game data for 2016020207 already exists in local cache.
# Game data for 2016020208 already exists in local cache.
# Game data for 2016020209 already exists in local cache.
# Game data for 2016020210 already exists in local cache.
# Game data for 2016020211 already exists in local cache.
# Game data for 2016020212 already exists in local cache.
# Game data for 2016020213 already exists in local cache.
# Game data for 2016020214 already exists in local cache.
# Game data for 2016020215 already exists in local cache.
# Game data for 2016020216 already exists in local cache.
# Game data for 2016020217 already exists in local cache.
# Game data for 2016020218 already exists in local cache.
# Game data for 2016020219 already exists in local cache.
# Game data for 2016020220 already exists in local cache.
# Game data for 2016020221 already exists in local cache.
# Game data for 2016020222 already exists in local cache.
# Game data for 2016020223 already exists in local cache.
# Game data for 2016020224 already exists in local cache.
# Game data for 2016020225 already exists in local cache.
# Game data for 2016020226 already exists in local cache.
# Game data for 2016020227 already exists in local cache.
# Game data for 2016020228 already exists in local cache.
# Game data for 2016020229 already exists in local cache.
# Game data for 2016020230 already exists in local cache.
# Game data for 2016020231 already exists in local cache.
# Game data for 2016020232 already exists in local cache.
# Game data for 2016020233 already exists in local cache.
# Game data for 2016020234 already exists in local cache.
# Game data for 2016020235 already exists in local cache.
# Game data for 2016020236 already exists in local cache.
# Game data for 2016020237 already exists in local cache.
# Game data for 2016020238 already exists in local cache.
# Game data for 2016020239 already exists in local cache.
# Game data for 2016020240 already exists in local cache.
# Game data for 2016020241 already exists in local cache.
# Game data for 2016020242 already exists in local cache.
# Game data for 2016020243 already exists in local cache.
# Game data for 2016020244 already exists in local cache.
# Game data for 2016020245 already exists in local cache.
# Game data for 2016020246 already exists in local cache.
# Game data for 2016020247 already exists in local cache.
# Game data for 2016020248 already exists in local cache.
# Game data for 2016020249 already exists in local cache.
# Game data for 2016020250 already exists in local cache.
# Game data for 2016020251 already exists in local cache.
# Game data for 2016020252 already exists in local cache.
# Game data for 2016020253 already exists in local cache.
# Game data for 2016020254 already exists in local cache.
# Game data for 2016020255 already exists in local cache.
# Game data for 2016020256 already exists in local cache.
# Game data for 2016020257 already exists in local cache.
# Game data for 2016020258 already exists in local cache.
# Game data for 2016020259 already exists in local cache.
# Game data for 2016020260 already exists in local cache.
# Game data for 2016020261 already exists in local cache.
# Game data for 2016020262 already exists in local cache.
# Game data for 2016020263 already exists in local cache.
# Game data for 2016020264 already exists in local cache.
# Game data for 2016020265 already exists in local cache.
# Game data for 2016020266 already exists in local cache.
# Game data for 2016020267 already exists in local cache.
# Game data for 2016020268 already exists in local cache.
# Game data for 2016020269 already exists in local cache.
# Game data for 2016020270 already exists in local cache.
# Game data for 2016020271 already exists in local cache.
# Game data for 2016020272 already exists in local cache.
# Game data for 2016020273 already exists in local cache.
# Game data for 2016020274 already exists in local cache.
# Game data for 2016020275 already exists in local cache.
# Game data for 2016020276 already exists in local cache.
# Game data for 2016020277 already exists in local cache.
# Game data for 2016020278 already exists in local cache.
# Game data for 2016020279 already exists in local cache.
# Game data for 2016020280 already exists in local cache.
# Game data for 2016020281 already exists in local cache.
# Game data for 2016020282 already exists in local cache.
# Game data for 2016020283 already exists in local cache.
# Game data for 2016020284 already exists in local cache.
# Game data for 2016020285 already exists in local cache.
# Game data for 2016020286 already exists in local cache.
# Game data for 2016020287 already exists in local cache.
# Game data for 2016020288 already exists in local cache.
# Game data for 2016020289 already exists in local cache.
# Game data for 2016020290 already exists in local cache.
# Game data for 2016020291 already exists in local cache.
# Game data for 2016020292 already exists in local cache.
# Game data for 2016020293 already exists in local cache.
# Game data for 2016020294 already exists in local cache.
# Game data for 2016020295 already exists in local cache.
# Game data for 2016020296 already exists in local cache.
# Game data for 2016020297 already exists in local cache.
# Game data for 2016020298 already exists in local cache.
# Game data for 2016020299 already exists in local cache.
# Game data for 2016020300 already exists in local cache.
# Game data for 2016020301 already exists in local cache.
# Game data for 2016020302 already exists in local cache.
# Game data for 2016020303 already exists in local cache.
# Game data for 2016020304 already exists in local cache.
# Game data for 2016020305 already exists in local cache.
# Game data for 2016020306 already exists in local cache.
# Game data for 2016020307 already exists in local cache.
# Game data for 2016020308 already exists in local cache.
# Game data for 2016020309 already exists in local cache.
# Game data for 2016020310 already exists in local cache.
# Game data for 2016020311 already exists in local cache.
# Game data for 2016020312 already exists in local cache.
# Game data for 2016020313 already exists in local cache.
# Game data for 2016020314 already exists in local cache.
# Game data for 2016020315 already exists in local cache.
# Game data for 2016020316 already exists in local cache.
# Game data for 2016020317 already exists in local cache.
# Game data for 2016020318 already exists in local cache.
# Game data for 2016020319 already exists in local cache.
# Game data for 2016020320 already exists in local cache.
# Game data for 2016020321 already exists in local cache.
# Game data for 2016020322 already exists in local cache.
# Game data for 2016020323 already exists in local cache.
# Game data for 2016020324 already exists in local cache.
# Game data for 2016020325 already exists in local cache.
# Game data for 2016020326 already exists in local cache.
# Game data for 2016020327 already exists in local cache.
# Game data for 2016020328 already exists in local cache.
# Game data for 2016020329 already exists in local cache.
# Game data for 2016020330 already exists in local cache.
# Game data for 2016020331 already exists in local cache.
# Game data for 2016020332 already exists in local cache.
# Game data for 2016020333 already exists in local cache.
# Game data for 2016020334 already exists in local cache.
# Game data for 2016020335 already exists in local cache.
# Game data for 2016020336 already exists in local cache.
# Game data for 2016020337 already exists in local cache.
# Game data for 2016020338 already exists in local cache.
# Game data for 2016020339 already exists in local cache.
# Game data for 2016020340 already exists in local cache.
# Game data for 2016020341 already exists in local cache.
# Game data for 2016020342 already exists in local cache.
# Game data for 2016020343 already exists in local cache.
# Game data for 2016020344 already exists in local cache.
# Game data for 2016020345 already exists in local cache.
# Game data for 2016020346 already exists in local cache.
# Game data for 2016020347 already exists in local cache.
# Game data for 2016020348 already exists in local cache.
# Game data for 2016020349 already exists in local cache.
# Game data for 2016020350 already exists in local cache.
# Game data for 2016020351 already exists in local cache.
# Game data for 2016020352 already exists in local cache.
# Game data for 2016020353 already exists in local cache.
# Game data for 2016020354 already exists in local cache.
# Game data for 2016020355 already exists in local cache.
# Game data for 2016020356 already exists in local cache.
# Game data for 2016020357 already exists in local cache.
# Game data for 2016020358 already exists in local cache.
# Game data for 2016020359 already exists in local cache.
# Game data for 2016020360 already exists in local cache.
# Game data for 2016020361 already exists in local cache.
# Game data for 2016020362 already exists in local cache.
# Game data for 2016020363 already exists in local cache.
# Game data for 2016020364 already exists in local cache.
# Game data for 2016020365 already exists in local cache.
# Game data for 2016020366 already exists in local cache.
# Game data for 2016020367 already exists in local cache.
# Game data for 2016020368 already exists in local cache.
# Game data for 2016020369 already exists in local cache.
# Game data for 2016020370 already exists in local cache.
# Game data for 2016020371 already exists in local cache.
# Game data for 2016020372 already exists in local cache.
# Game data for 2016020373 already exists in local cache.
# Game data for 2016020374 already exists in local cache.
# Game data for 2016020375 already exists in local cache.
# Game data for 2016020376 already exists in local cache.
# Game data for 2016020377 already exists in local cache.
# Game data for 2016020378 already exists in local cache.
# Game data for 2016020379 already exists in local cache.
# Game data for 2016020380 already exists in local cache.
# Game data for 2016020381 already exists in local cache.
# Game data for 2016020382 already exists in local cache.
# Game data for 2016020383 already exists in local cache.
# Game data for 2016020384 already exists in local cache.
# Game data for 2016020385 already exists in local cache.
# Game data for 2016020386 already exists in local cache.
# Game data for 2016020387 already exists in local cache.
# Game data for 2016020388 already exists in local cache.
# Game data for 2016020389 already exists in local cache.
# Game data for 2016020390 already exists in local cache.
# Game data for 2016020391 already exists in local cache.
# Game data for 2016020392 already exists in local cache.
# Game data for 2016020393 already exists in local cache.
# Game data for 2016020394 already exists in local cache.
# Game data for 2016020395 already exists in local cache.
# Game data for 2016020396 already exists in local cache.
# Game data for 2016020397 already exists in local cache.
# Game data for 2016020398 already exists in local cache.
# Game data for 2016020399 already exists in local cache.
# Game data for 2016020400 already exists in local cache.
# Game data for 2016020401 already exists in local cache.
# Game data for 2016020402 already exists in local cache.
# Game data for 2016020403 already exists in local cache.
# Game data for 2016020404 already exists in local cache.
# Game data for 2016020405 already exists in local cache.
# Game data for 2016020406 already exists in local cache.
# Game data for 2016020407 already exists in local cache.
# Game data for 2016020408 already exists in local cache.
# Game data for 2016020409 already exists in local cache.
# Game data for 2016020410 already exists in local cache.
# Game data for 2016020411 already exists in local cache.
# Game data for 2016020412 already exists in local cache.
# Game data for 2016020413 already exists in local cache.
# Game data for 2016020414 already exists in local cache.
# Game data for 2016020415 already exists in local cache.
# Game data for 2016020416 already exists in local cache.
# Game data for 2016020417 already exists in local cache.
# Game data for 2016020418 already exists in local cache.
# Game data for 2016020419 already exists in local cache.
# Game data for 2016020420 already exists in local cache.
# Game data for 2016020421 already exists in local cache.
# Game data for 2016020422 already exists in local cache.
# Game data for 2016020423 already exists in local cache.
# Game data for 2016020424 already exists in local cache.
# Game data for 2016020425 already exists in local cache.
# Game data for 2016020426 already exists in local cache.
# Game data for 2016020427 already exists in local cache.
# Game data for 2016020428 already exists in local cache.
# Game data for 2016020429 already exists in local cache.
# Game data for 2016020430 already exists in local cache.
# Game data for 2016020431 already exists in local cache.
# Game data for 2016020432 already exists in local cache.
# Game data for 2016020433 already exists in local cache.
# Game data for 2016020434 already exists in local cache.
# Game data for 2016020435 already exists in local cache.
# Game data for 2016020436 already exists in local cache.
# Game data for 2016020437 already exists in local cache.
# Game data for 2016020438 already exists in local cache.
# Game data for 2016020439 already exists in local cache.
# Game data for 2016020440 already exists in local cache.
# Game data for 2016020441 already exists in local cache.
# Game data for 2016020442 already exists in local cache.
# Game data for 2016020443 already exists in local cache.
# Game data for 2016020444 already exists in local cache.
# Game data for 2016020445 already exists in local cache.
# Game data for 2016020446 already exists in local cache.
# Game data for 2016020447 already exists in local cache.
# Game data for 2016020448 already exists in local cache.
# Game data for 2016020449 already exists in local cache.
# Game data for 2016020450 already exists in local cache.
# Game data for 2016020451 already exists in local cache.
# Game data for 2016020452 already exists in local cache.
# Game data for 2016020453 already exists in local cache.
# Game data for 2016020454 already exists in local cache.
# Game data for 2016020455 already exists in local cache.
# Game data for 2016020456 already exists in local cache.
# Game data for 2016020457 already exists in local cache.
# Game data for 2016020458 already exists in local cache.
# Game data for 2016020459 already exists in local cache.
# Game data for 2016020460 already exists in local cache.
# Game data for 2016020461 already exists in local cache.
# Game data for 2016020462 already exists in local cache.
# Game data for 2016020463 already exists in local cache.
# Game data for 2016020464 already exists in local cache.
# Game data for 2016020465 already exists in local cache.
# Game data for 2016020466 already exists in local cache.
# Game data for 2016020467 already exists in local cache.
# Game data for 2016020468 already exists in local cache.
# Game data for 2016020469 already exists in local cache.
# Game data for 2016020470 already exists in local cache.
# Game data for 2016020471 already exists in local cache.
# Game data for 2016020472 already exists in local cache.
# Game data for 2016020473 already exists in local cache.
# Game data for 2016020474 already exists in local cache.
# Game data for 2016020475 already exists in local cache.
# Game data for 2016020476 already exists in local cache.
# Game data for 2016020477 already exists in local cache.
# Game data for 2016020478 already exists in local cache.
# Game data for 2016020479 already exists in local cache.
# Game data for 2016020480 already exists in local cache.
# Game data for 2016020481 already exists in local cache.
# Game data for 2016020482 already exists in local cache.
# Game data for 2016020483 already exists in local cache.
# Game data for 2016020484 already exists in local cache.
# Game data for 2016020485 already exists in local cache.
# Game data for 2016020486 already exists in local cache.
# Game data for 2016020487 already exists in local cache.
# Game data for 2016020488 already exists in local cache.
# Game data for 2016020489 already exists in local cache.
# Game data for 2016020490 already exists in local cache.
# Game data for 2016020491 already exists in local cache.
# Game data for 2016020492 already exists in local cache.
# Game data for 2016020493 already exists in local cache.
# Game data for 2016020494 already exists in local cache.
# Game data for 2016020495 already exists in local cache.
# Game data for 2016020496 already exists in local cache.
# Game data for 2016020497 already exists in local cache.
# Game data for 2016020498 already exists in local cache.
# Game data for 2016020499 already exists in local cache.
# Game data for 2016020500 already exists in local cache.
# Game data for 2016020501 already exists in local cache.
# Game data for 2016020502 already exists in local cache.
# Game data for 2016020503 already exists in local cache.
# Game data for 2016020504 already exists in local cache.
# Game data for 2016020505 already exists in local cache.
# Game data for 2016020506 already exists in local cache.
# Game data for 2016020507 already exists in local cache.
# Game data for 2016020508 already exists in local cache.
# Game data for 2016020509 already exists in local cache.
# Game data for 2016020510 already exists in local cache.
# Game data for 2016020511 already exists in local cache.
# Game data for 2016020512 already exists in local cache.
# Game data for 2016020513 already exists in local cache.
# Game data for 2016020514 already exists in local cache.
# Game data for 2016020515 already exists in local cache.
# Game data for 2016020516 already exists in local cache.
# Game data for 2016020517 already exists in local cache.
# Game data for 2016020518 already exists in local cache.
# Game data for 2016020519 already exists in local cache.
# Game data for 2016020520 already exists in local cache.
# Game data for 2016020521 already exists in local cache.
# Game data for 2016020522 already exists in local cache.
# Game data for 2016020523 already exists in local cache.
# Game data for 2016020524 already exists in local cache.
# Game data for 2016020525 already exists in local cache.
# Game data for 2016020526 already exists in local cache.
# Game data for 2016020527 already exists in local cache.
# Game data for 2016020528 already exists in local cache.
# Game data for 2016020529 already exists in local cache.
# Game data for 2016020530 already exists in local cache.
# Game data for 2016020531 already exists in local cache.
# Game data for 2016020532 already exists in local cache.
# Game data for 2016020533 already exists in local cache.
# Game data for 2016020534 already exists in local cache.
# Game data for 2016020535 already exists in local cache.
# Game data for 2016020536 already exists in local cache.
# Game data for 2016020537 already exists in local cache.
# Game data for 2016020538 already exists in local cache.
# Game data for 2016020539 already exists in local cache.
# Game data for 2016020540 already exists in local cache.
# Game data for 2016020541 already exists in local cache.
# Game data for 2016020542 already exists in local cache.
# Game data for 2016020543 already exists in local cache.
# Game data for 2016020544 already exists in local cache.
# Game data for 2016020545 already exists in local cache.
# Game data for 2016020546 already exists in local cache.
# Game data for 2016020547 already exists in local cache.
# Game data for 2016020548 already exists in local cache.
# Game data for 2016020549 already exists in local cache.
# Game data for 2016020550 already exists in local cache.
# Game data for 2016020551 already exists in local cache.
# Game data for 2016020552 already exists in local cache.
# Game data for 2016020553 already exists in local cache.
# Game data for 2016020554 already exists in local cache.
# Game data for 2016020555 already exists in local cache.
# Game data for 2016020556 already exists in local cache.
# Game data for 2016020557 already exists in local cache.
# Game data for 2016020558 already exists in local cache.
# Game data for 2016020559 already exists in local cache.
# Game data for 2016020560 already exists in local cache.
# Game data for 2016020561 already exists in local cache.
# Game data for 2016020562 already exists in local cache.
# Game data for 2016020563 already exists in local cache.
# Game data for 2016020564 already exists in local cache.
# Game data for 2016020565 already exists in local cache.
# Game data for 2016020566 already exists in local cache.
# Game data for 2016020567 already exists in local cache.
# Game data for 2016020568 already exists in local cache.
# Game data for 2016020569 already exists in local cache.
# Game data for 2016020570 already exists in local cache.
# Game data for 2016020571 already exists in local cache.
# Game data for 2016020572 already exists in local cache.
# Game data for 2016020573 already exists in local cache.
# Game data for 2016020574 already exists in local cache.
# Game data for 2016020575 already exists in local cache.
# Game data for 2016020576 already exists in local cache.
# Game data for 2016020577 already exists in local cache.
# Game data for 2016020578 already exists in local cache.
# Game data for 2016020579 already exists in local cache.
# Game data for 2016020580 already exists in local cache.
# Game data for 2016020581 already exists in local cache.
# Game data for 2016020582 already exists in local cache.
# Game data for 2016020583 already exists in local cache.
# Game data for 2016020584 already exists in local cache.
# Game data for 2016020585 already exists in local cache.
# Game data for 2016020586 already exists in local cache.
# Game data for 2016020587 already exists in local cache.
# Game data for 2016020588 already exists in local cache.
# Game data for 2016020589 already exists in local cache.
# Game data for 2016020590 already exists in local cache.
# Game data for 2016020591 already exists in local cache.
# Game data for 2016020592 already exists in local cache.
# Game data for 2016020593 already exists in local cache.
# Game data for 2016020594 already exists in local cache.
# Game data for 2016020595 already exists in local cache.
# Game data for 2016020596 already exists in local cache.
# Game data for 2016020597 already exists in local cache.
# Game data for 2016020598 already exists in local cache.
# Game data for 2016020599 already exists in local cache.
# Game data for 2016020600 already exists in local cache.
# Game data for 2016020601 already exists in local cache.
# Game data for 2016020602 already exists in local cache.
# Game data for 2016020603 already exists in local cache.
# Game data for 2016020604 already exists in local cache.
# Game data for 2016020605 already exists in local cache.
# Game data for 2016020606 already exists in local cache.
# Game data for 2016020607 already exists in local cache.
# Game data for 2016020608 already exists in local cache.
# Game data for 2016020609 already exists in local cache.
# Game data for 2016020610 already exists in local cache.
# Game data for 2016020611 already exists in local cache.
# Game data for 2016020612 already exists in local cache.
# Game data for 2016020613 already exists in local cache.
# Game data for 2016020614 already exists in local cache.
# Game data for 2016020615 already exists in local cache.
# Game data for 2016020616 already exists in local cache.
# Game data for 2016020617 already exists in local cache.
# Game data for 2016020618 already exists in local cache.
# Game data for 2016020619 already exists in local cache.
# Game data for 2016020620 already exists in local cache.
# Game data for 2016020621 already exists in local cache.
# Game data for 2016020622 already exists in local cache.
# Game data for 2016020623 already exists in local cache.
# Game data for 2016020624 already exists in local cache.
# Game data for 2016020625 already exists in local cache.
# Game data for 2016020626 already exists in local cache.
# Game data for 2016020627 already exists in local cache.
# Game data for 2016020628 already exists in local cache.
# Game data for 2016020629 already exists in local cache.
# Game data for 2016020630 already exists in local cache.
# Game data for 2016020631 already exists in local cache.
# Game data for 2016020632 already exists in local cache.
# Game data for 2016020633 already exists in local cache.
# Game data for 2016020634 already exists in local cache.
# Game data for 2016020635 already exists in local cache.
# Game data for 2016020636 already exists in local cache.
# Game data for 2016020637 already exists in local cache.
# Game data for 2016020638 already exists in local cache.
# Game data for 2016020639 already exists in local cache.
# Game data for 2016020640 already exists in local cache.
# Game data for 2016020641 already exists in local cache.
# Game data for 2016020642 already exists in local cache.
# Game data for 2016020643 already exists in local cache.
# Game data for 2016020644 already exists in local cache.
# Game data for 2016020645 already exists in local cache.
# Game data for 2016020646 already exists in local cache.
# Game data for 2016020647 already exists in local cache.
# Game data for 2016020648 already exists in local cache.
# Game data for 2016020649 already exists in local cache.
# Game data for 2016020650 already exists in local cache.
# Game data for 2016020651 already exists in local cache.
# Game data for 2016020652 already exists in local cache.
# Game data for 2016020653 already exists in local cache.
# Game data for 2016020654 already exists in local cache.
# Game data for 2016020655 already exists in local cache.
# Game data for 2016020656 already exists in local cache.
# Game data for 2016020657 already exists in local cache.
# Game data for 2016020658 already exists in local cache.
# Game data for 2016020659 already exists in local cache.
# Game data for 2016020660 already exists in local cache.
# Game data for 2016020661 already exists in local cache.
# Game data for 2016020662 already exists in local cache.
# Game data for 2016020663 already exists in local cache.
# Game data for 2016020664 already exists in local cache.
# Game data for 2016020665 already exists in local cache.
# Game data for 2016020666 already exists in local cache.
# Game data for 2016020667 already exists in local cache.
# Game data for 2016020668 already exists in local cache.
# Game data for 2016020669 already exists in local cache.
# Game data for 2016020670 already exists in local cache.
# Game data for 2016020671 already exists in local cache.
# Game data for 2016020672 already exists in local cache.
# Game data for 2016020673 already exists in local cache.
# Game data for 2016020674 already exists in local cache.
# Game data for 2016020675 already exists in local cache.
# Game data for 2016020676 already exists in local cache.
# Game data for 2016020677 already exists in local cache.
# Game data for 2016020678 already exists in local cache.
# Game data for 2016020679 already exists in local cache.
# Game data for 2016020680 already exists in local cache.
# Game data for 2016020681 already exists in local cache.
# Game data for 2016020682 already exists in local cache.
# Game data for 2016020683 already exists in local cache.
# Game data for 2016020684 already exists in local cache.
# Game data for 2016020685 already exists in local cache.
# Game data for 2016020686 already exists in local cache.
# Game data for 2016020687 already exists in local cache.
# Game data for 2016020688 already exists in local cache.
# Game data for 2016020689 already exists in local cache.
# Game data for 2016020690 already exists in local cache.
# Game data for 2016020691 already exists in local cache.
# Game data for 2016020692 already exists in local cache.
# Game data for 2016020693 already exists in local cache.
# Game data for 2016020694 already exists in local cache.
# Game data for 2016020695 already exists in local cache.
# Game data for 2016020696 already exists in local cache.
# Game data for 2016020697 already exists in local cache.
# Game data for 2016020698 already exists in local cache.
# Game data for 2016020699 already exists in local cache.
# Game data for 2016020700 already exists in local cache.
# Game data for 2016020701 already exists in local cache.
# Game data for 2016020702 already exists in local cache.
# Game data for 2016020703 already exists in local cache.
# Game data for 2016020704 already exists in local cache.
# Game data for 2016020705 already exists in local cache.
# Game data for 2016020706 already exists in local cache.
# Game data for 2016020707 already exists in local cache.
# Game data for 2016020708 already exists in local cache.
# Game data for 2016020709 already exists in local cache.
# Game data for 2016020710 already exists in local cache.
# Game data for 2016020711 already exists in local cache.
# Game data for 2016020712 already exists in local cache.
# Game data for 2016020713 already exists in local cache.
# Game data for 2016020714 already exists in local cache.
# Game data for 2016020715 already exists in local cache.
# Game data for 2016020716 already exists in local cache.
# Game data for 2016020717 already exists in local cache.
# Game data for 2016020718 already exists in local cache.
# Game data for 2016020719 already exists in local cache.
# Game data for 2016020720 already exists in local cache.
# Game data for 2016020721 already exists in local cache.
# Game data for 2016020722 already exists in local cache.
# Game data for 2016020723 already exists in local cache.
# Game data for 2016020724 already exists in local cache.
# Game data for 2016020725 already exists in local cache.
# Game data for 2016020726 already exists in local cache.
# Game data for 2016020727 already exists in local cache.
# Game data for 2016020728 already exists in local cache.
# Game data for 2016020729 already exists in local cache.
# Game data for 2016020730 already exists in local cache.
# Game data for 2016020731 already exists in local cache.
# Game data for 2016020732 already exists in local cache.
# Game data for 2016020733 already exists in local cache.
# Game data for 2016020734 already exists in local cache.
# Game data for 2016020735 already exists in local cache.
# Game data for 2016020736 already exists in local cache.
# Game data for 2016020737 already exists in local cache.
# Game data for 2016020738 already exists in local cache.
# Game data for 2016020739 already exists in local cache.
# Game data for 2016020740 already exists in local cache.
# Game data for 2016020741 already exists in local cache.
# Game data for 2016020742 already exists in local cache.
# Game data for 2016020743 already exists in local cache.
# Game data for 2016020744 already exists in local cache.
# Game data for 2016020745 already exists in local cache.
# Game data for 2016020746 already exists in local cache.
# Game data for 2016020747 already exists in local cache.
# Game data for 2016020748 already exists in local cache.
# Game data for 2016020749 already exists in local cache.
# Game data for 2016020750 already exists in local cache.
# Game data for 2016020751 already exists in local cache.
# Game data for 2016020752 already exists in local cache.
# Game data for 2016020753 already exists in local cache.
# Game data for 2016020754 already exists in local cache.
# Game data for 2016020755 already exists in local cache.
# Game data for 2016020756 already exists in local cache.
# Game data for 2016020757 already exists in local cache.
# Game data for 2016020758 already exists in local cache.
# Game data for 2016020759 already exists in local cache.
# Game data for 2016020760 already exists in local cache.
# Game data for 2016020761 already exists in local cache.
# Game data for 2016020762 already exists in local cache.
# Game data for 2016020763 already exists in local cache.
# Game data for 2016020764 already exists in local cache.
# Game data for 2016020765 already exists in local cache.
# Game data for 2016020766 already exists in local cache.
# Game data for 2016020767 already exists in local cache.
# Game data for 2016020768 already exists in local cache.
# Game data for 2016020769 already exists in local cache.
# Game data for 2016020770 already exists in local cache.
# Game data for 2016020771 already exists in local cache.
# Game data for 2016020772 already exists in local cache.
# Game data for 2016020773 already exists in local cache.
# Game data for 2016020774 already exists in local cache.
# Game data for 2016020775 already exists in local cache.
# Game data for 2016020776 already exists in local cache.
# Game data for 2016020777 already exists in local cache.
# Game data for 2016020778 already exists in local cache.
# Game data for 2016020779 already exists in local cache.
# Game data for 2016020780 already exists in local cache.
# Game data for 2016020781 already exists in local cache.
# Game data for 2016020782 already exists in local cache.
# Game data for 2016020783 already exists in local cache.
# Game data for 2016020784 already exists in local cache.
# Game data for 2016020785 already exists in local cache.
# Game data for 2016020786 already exists in local cache.
# Game data for 2016020787 already exists in local cache.
# Game data for 2016020788 already exists in local cache.
# Game data for 2016020789 already exists in local cache.
# Game data for 2016020790 already exists in local cache.
# Game data for 2016020791 already exists in local cache.
# Game data for 2016020792 already exists in local cache.
# Game data for 2016020793 already exists in local cache.
# Game data for 2016020794 already exists in local cache.
# Game data for 2016020795 already exists in local cache.
# Game data for 2016020796 already exists in local cache.
# Game data for 2016020797 already exists in local cache.
# Game data for 2016020798 already exists in local cache.
# Game data for 2016020799 already exists in local cache.
# Game data for 2016020800 already exists in local cache.
# Game data for 2016020801 already exists in local cache.
# Game data for 2016020802 already exists in local cache.
# Game data for 2016020803 already exists in local cache.
# Game data for 2016020804 already exists in local cache.
# Game data for 2016020805 already exists in local cache.
# Game data for 2016020806 already exists in local cache.
# Game data for 2016020807 already exists in local cache.
# Game data for 2016020808 already exists in local cache.
# Game data for 2016020809 already exists in local cache.
# Game data for 2016020810 already exists in local cache.
# Game data for 2016020811 already exists in local cache.
# Game data for 2016020812 already exists in local cache.
# Game data for 2016020813 already exists in local cache.
# Game data for 2016020814 already exists in local cache.
# Game data for 2016020815 already exists in local cache.
# Game data for 2016020816 already exists in local cache.
# Game data for 2016020817 already exists in local cache.
# Game data for 2016020818 already exists in local cache.
# Game data for 2016020819 already exists in local cache.
# Game data for 2016020820 already exists in local cache.
# Game data for 2016020821 already exists in local cache.
# Game data for 2016020822 already exists in local cache.
# Game data for 2016020823 already exists in local cache.
# Game data for 2016020824 already exists in local cache.
# Game data for 2016020825 already exists in local cache.
# Game data for 2016020826 already exists in local cache.
# Game data for 2016020827 already exists in local cache.
# Game data for 2016020828 already exists in local cache.
# Game data for 2016020829 already exists in local cache.
# Game data for 2016020830 already exists in local cache.
# Game data for 2016020831 already exists in local cache.
# Game data for 2016020832 already exists in local cache.
# Game data for 2016020833 already exists in local cache.
# Game data for 2016020834 already exists in local cache.
# Game data for 2016020835 already exists in local cache.
# Game data for 2016020836 already exists in local cache.
# Game data for 2016020837 already exists in local cache.
# Game data for 2016020838 already exists in local cache.
# Game data for 2016020839 already exists in local cache.
# Game data for 2016020840 already exists in local cache.
# Game data for 2016020841 already exists in local cache.
# Game data for 2016020842 already exists in local cache.
# Game data for 2016020843 already exists in local cache.
# Game data for 2016020844 already exists in local cache.
# Game data for 2016020845 already exists in local cache.
# Game data for 2016020846 already exists in local cache.
# Game data for 2016020847 already exists in local cache.
# Game data for 2016020848 already exists in local cache.
# Game data for 2016020849 already exists in local cache.
# Game data for 2016020850 already exists in local cache.
# Game data for 2016020851 already exists in local cache.
# Game data for 2016020852 already exists in local cache.
# Game data for 2016020853 already exists in local cache.
# Game data for 2016020854 already exists in local cache.
# Game data for 2016020855 already exists in local cache.
# Game data for 2016020856 already exists in local cache.
# Game data for 2016020857 already exists in local cache.
# ...
# Game data for 2021021256 already exists in local cache.
# Game data for 2021021257 already exists in local cache.
# Game data for 2021021258 already exists in local cache.
# Game data for 2021021259 already exists in local cache.
# Game data for 2021021260 already exists in local cache.
# Game data for 2021021261 already exists in local cache.
# Game data for 2021021262 already exists in local cache.
# Game data for 2021021263 already exists in local cache.
# Game data for 2021021264 already exists in local cache.
# Game data for 2021021265 already exists in local cache.
# Game data for 2021021266 already exists in local cache.
# Game data for 2021021267 already exists in local cache.
# Game data for 2021021268 already exists in local cache.
# Game data for 2021021269 already exists in local cache.
# Game data for 2021021270 already exists in local cache.
# Game data for 2021021271 already exists in local cache.
# Game data for 2021021272 already exists in local cache.
# Game data for 2021021273 already exists in local cache.
# Game data for 2021021274 already exists in local cache.
# Game data for 2021021275 already exists in local cache.
# Game data for 2021021276 already exists in local cache.
# Game data for 2021021277 already exists in local cache.
# Game data for 2021021278 already exists in local cache.
# Game data for 2021021279 already exists in local cache.
# Game data for 2021021280 already exists in local cache.
# Game data for 2021021281 already exists in local cache.
# Game data for 2021021282 already exists in local cache.
# Game data for 2021021283 already exists in local cache.
# Game data for 2021021284 already exists in local cache.
# Game data for 2021021285 already exists in local cache.
# Game data for 2021021286 already exists in local cache.
# Game data for 2021021287 already exists in local cache.
# Game data for 2021021288 already exists in local cache.
# Game data for 2021021289 already exists in local cache.
# Game data for 2021021290 already exists in local cache.
# Game data for 2021021291 already exists in local cache.
# Game data for 2021021292 already exists in local cache.
# Game data for 2021021293 already exists in local cache.
# Game data for 2021021294 already exists in local cache.
# Game data for 2021021295 already exists in local cache.
# Game data for 2021021296 already exists in local cache.
# Game data for 2021021297 already exists in local cache.
# Game data for 2021021298 already exists in local cache.
# Game data for 2021021299 already exists in local cache.
# Game data for 2021021300 already exists in local cache.
# Game data for 2021021301 already exists in local cache.
# Game data for 2021021302 already exists in local cache.
# Game data for 2021021303 already exists in local cache.
# Game data for 2021021304 already exists in local cache.
# Game data for 2021021305 already exists in local cache.
# Game data for 2021021306 already exists in local cache.
# Game data for 2021021307 already exists in local cache.
# Game data for 2021021308 already exists in local cache.
# Game data for 2021021309 already exists in local cache.
# Game data for 2021021310 already exists in local cache.
# Game data for 2021021311 already exists in local cache.
# Game data for 2021021312 already exists in local cache.
# Failed to download data for game 2021021313.
# Failed to download data for game 2021021314.
# Failed to download data for game 2021021315.
# Failed to download data for game 2021021316.
# Failed to download data for game 2021021317.
# Failed to download data for game 2021021318.
# Failed to download data for game 2021021319.
# Failed to download data for game 2021021320.
# Failed to download data for game 2021021321.
# Failed to download data for game 2021021322.
# Failed to download data for game 2021021323.
# Failed to download data for game 2021021324.
# Failed to download data for game 2021021325.
# Failed to download data for game 2021021326.
# Failed to download data for game 2021021327.
# Failed to download data for game 2021021328.
# Failed to download data for game 2021021329.
# Failed to download data for game 2021021330.
# Failed to download data for game 2021021331.
# Failed to download data for game 2021021332.
# Failed to download data for game 2021021333.
# Failed to download data for game 2021021334.
# Failed to download data for game 2021021335.
# Failed to download data for game 2021021336.
# Failed to download data for game 2021021337.
# Failed to download data for game 2021021338.
# Failed to download data for game 2021021339.
# Failed to download data for game 2021021340.
# Failed to download data for game 2021021341.
# Failed to download data for game 2021021342.
# Failed to download data for game 2021021343.
# Failed to download data for game 2021021344.
# Failed to download data for game 2021021345.
# Failed to download data for game 2021021346.
# Failed to download data for game 2021021347.
# Failed to download data for game 2021021348.
# Failed to download data for game 2021021349.
# Failed to download data for game 2021021350.
# Failed to download data for game 2021021351.
# Failed to download data for game 2021021352.
# Failed to download data for game 2021021353.
# Game data for 2021030111 already exists in local cache.
# Game data for 2021030112 already exists in local cache.
# Game data for 2021030113 already exists in local cache.
# Game data for 2021030114 already exists in local cache.
# Game data for 2021030115 already exists in local cache.
# Game data for 2021030116 already exists in local cache.
# Failed to download data for game 2021030117.
# Game data for 2021030121 already exists in local cache.
# Game data for 2021030122 already exists in local cache.
# Game data for 2021030123 already exists in local cache.
# Game data for 2021030124 already exists in local cache.
# Game data for 2021030125 already exists in local cache.
# Game data for 2021030126 already exists in local cache.
# Game data for 2021030127 already exists in local cache.
# Game data for 2021030131 already exists in local cache.
# Game data for 2021030132 already exists in local cache.
# Game data for 2021030133 already exists in local cache.
# Game data for 2021030134 already exists in local cache.
# Game data for 2021030135 already exists in local cache.
# Game data for 2021030136 already exists in local cache.
# Game data for 2021030137 already exists in local cache.
# Game data for 2021030141 already exists in local cache.
# Game data for 2021030142 already exists in local cache.
# Game data for 2021030143 already exists in local cache.
# Game data for 2021030144 already exists in local cache.
# Game data for 2021030145 already exists in local cache.
# Game data for 2021030146 already exists in local cache.
# Game data for 2021030147 already exists in local cache.
# Game data for 2021030151 already exists in local cache.
# Game data for 2021030152 already exists in local cache.
# Game data for 2021030153 already exists in local cache.
# Game data for 2021030154 already exists in local cache.
# Failed to download data for game 2021030155.
# Failed to download data for game 2021030156.
# Failed to download data for game 2021030157.
# Game data for 2021030161 already exists in local cache.
# Game data for 2021030162 already exists in local cache.
# Game data for 2021030163 already exists in local cache.
# Game data for 2021030164 already exists in local cache.
# Game data for 2021030165 already exists in local cache.
# Game data for 2021030166 already exists in local cache.
# Failed to download data for game 2021030167.
# Game data for 2021030171 already exists in local cache.
# Game data for 2021030172 already exists in local cache.
# Game data for 2021030173 already exists in local cache.
# Game data for 2021030174 already exists in local cache.
# Game data for 2021030175 already exists in local cache.
# Game data for 2021030176 already exists in local cache.
# Game data for 2021030177 already exists in local cache.
# Game data for 2021030181 already exists in local cache.
# Game data for 2021030182 already exists in local cache.
# Game data for 2021030183 already exists in local cache.
# Game data for 2021030184 already exists in local cache.
# Game data for 2021030185 already exists in local cache.
# Game data for 2021030186 already exists in local cache.
# Game data for 2021030187 already exists in local cache.
# Game data for 2021030211 already exists in local cache.
# Game data for 2021030212 already exists in local cache.
# Game data for 2021030213 already exists in local cache.
# Game data for 2021030214 already exists in local cache.
# Failed to download data for game 2021030215.
# Failed to download data for game 2021030216.
# Failed to download data for game 2021030217.
# Game data for 2021030221 already exists in local cache.
# Game data for 2021030222 already exists in local cache.
# Game data for 2021030223 already exists in local cache.
# Game data for 2021030224 already exists in local cache.
# Game data for 2021030225 already exists in local cache.
# Game data for 2021030226 already exists in local cache.
# Game data for 2021030227 already exists in local cache.
# Game data for 2021030231 already exists in local cache.
# Game data for 2021030232 already exists in local cache.
# Game data for 2021030233 already exists in local cache.
# Game data for 2021030234 already exists in local cache.
# Game data for 2021030235 already exists in local cache.
# Game data for 2021030236 already exists in local cache.
# Failed to download data for game 2021030237.
# Game data for 2021030241 already exists in local cache.
# Game data for 2021030242 already exists in local cache.
# Game data for 2021030243 already exists in local cache.
# Game data for 2021030244 already exists in local cache.
# Game data for 2021030245 already exists in local cache.
# Failed to download data for game 2021030246.
# Failed to download data for game 2021030247.
# Game data for 2021030311 already exists in local cache.
# Game data for 2021030312 already exists in local cache.
# Game data for 2021030313 already exists in local cache.
# Game data for 2021030314 already exists in local cache.
# Game data for 2021030315 already exists in local cache.
# Game data for 2021030316 already exists in local cache.
# Failed to download data for game 2021030317.
# Game data for 2021030321 already exists in local cache.
# Game data for 2021030322 already exists in local cache.
# Game data for 2021030323 already exists in local cache.
# Game data for 2021030324 already exists in local cache.
# Failed to download data for game 2021030325.
# Failed to download data for game 2021030326.
# Failed to download data for game 2021030327.
# Game data for 2021030411 already exists in local cache.
# Game data for 2021030412 already exists in local cache.
# Game data for 2021030413 already exists in local cache.
# Game data for 2021030414 already exists in local cache.
# Game data for 2021030415 already exists in local cache.
# Game data for 2021030416 already exists in local cache.
# Failed to download data for game 2021030417.
# Failed to download data for game 2022021313.
# Failed to download data for game 2022021314.
# Failed to download data for game 2022021315.
# Failed to download data for game 2022021316.
# Failed to download data for game 2022021317.
# Failed to download data for game 2022021318.
# Failed to download data for game 2022021319.
# Failed to download data for game 2022021320.
# Failed to download data for game 2022021321.
# Failed to download data for game 2022021322.
# Failed to download data for game 2022021323.
# Failed to download data for game 2022021324.
# Failed to download data for game 2022021325.
# Failed to download data for game 2022021326.
# Failed to download data for game 2022021327.
# Failed to download data for game 2022021328.
# Failed to download data for game 2022021329.
# Failed to download data for game 2022021330.
# Failed to download data for game 2022021331.
# Failed to download data for game 2022021332.
# Failed to download data for game 2022021333.
# Failed to download data for game 2022021334.
# Failed to download data for game 2022021335.
# Failed to download data for game 2022021336.
# Failed to download data for game 2022021337.
# Failed to download data for game 2022021338.
# Failed to download data for game 2022021339.
# Failed to download data for game 2022021340.
# Failed to download data for game 2022021341.
# Failed to download data for game 2022021342.
# Failed to download data for game 2022021343.
# Failed to download data for game 2022021344.
# Failed to download data for game 2022021345.
# Failed to download data for game 2022021346.
# Failed to download data for game 2022021347.
# Failed to download data for game 2022021348.
# Failed to download data for game 2022021349.
# Failed to download data for game 2022021350.
# Failed to download data for game 2022021351.
# Failed to download data for game 2022021352.
# Failed to download data for game 2022021353.
# Failed to download data for game 2022030127.
# Failed to download data for game 2022030137.
# Failed to download data for game 2022030167.
# Failed to download data for game 2022030176.
# Failed to download data for game 2022030177.
# Failed to download data for game 2022030187.
# Failed to download data for game 2022030216.
# Failed to download data for game 2022030217.
# Failed to download data for game 2022030226.
# Failed to download data for game 2022030227.
# Failed to download data for game 2022030247.
# Failed to download data for game 2022030315.
# Failed to download data for game 2022030316.
# Failed to download data for game 2022030317.
# Failed to download data for game 2022030327.
# Failed to download data for game 2022030416.
# Failed to download data for game 2022030417.
# Failed to download data for game 2023021313.
# Failed to download data for game 2023021314.
# Failed to download data for game 2023021315.
# Failed to download data for game 2023021316.
# Failed to download data for game 2023021317.
# Failed to download data for game 2023021318.
# Failed to download data for game 2023021319.
# Failed to download data for game 2023021320.
# Failed to download data for game 2023021321.
# Failed to download data for game 2023021322.
# Failed to download data for game 2023021323.
# Failed to download data for game 2023021324.
# Failed to download data for game 2023021325.
# Failed to download data for game 2023021326.
# Failed to download data for game 2023021327.
# Failed to download data for game 2023021328.
# Failed to download data for game 2023021329.
# Failed to download data for game 2023021330.
# Failed to download data for game 2023021331.
# Failed to download data for game 2023021332.
# Failed to download data for game 2023021333.
# Failed to download data for game 2023021334.
# Failed to download data for game 2023021335.
# Failed to download data for game 2023021336.
# Failed to download data for game 2023021337.
# Failed to download data for game 2023021338.
# Failed to download data for game 2023021339.
# Failed to download data for game 2023021340.
# Failed to download data for game 2023021341.
# Failed to download data for game 2023021342.
# Failed to download data for game 2023021343.
# Failed to download data for game 2023021344.
# Failed to download data for game 2023021345.
# Failed to download data for game 2023021346.
# Failed to download data for game 2023021347.
# Failed to download data for game 2023021348.
# Failed to download data for game 2023021349.
# Failed to download data for game 2023021350.
# Failed to download data for game 2023021351.
# Failed to download data for game 2023021352.
# Failed to download data for game 2023021353.
# Failed to download data for game 2023030116.
# Failed to download data for game 2023030117.
# Failed to download data for game 2023030135.
# Failed to download data for game 2023030136.
# Failed to download data for game 2023030137.
# Failed to download data for game 2023030146.
# Failed to download data for game 2023030147.
# Failed to download data for game 2023030166.
# Failed to download data for game 2023030167.
# Failed to download data for game 2023030177.
# Failed to download data for game 2023030186.
# Failed to download data for game 2023030187.
# Failed to download data for game 2023030217.
# Failed to download data for game 2023030227.
# Failed to download data for game 2023030237.
# Failed to download data for game 2023030317.
# Failed to download data for game 2023030327.

# %% [markdown]
# 2. Interactive debug ipywidget to explore the data.

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import json

# %%
downloader = NHLDataDownloader()
# Global data storage
all_games = {}
game_id = ""
event_id = ""

# Widgets to select season, season type, game ID, and event ID
season = widgets.Dropdown(options=[str(year) for year in range(2016, 2024)], description='Season')
season_type = widgets.Dropdown(options=['Regular Season', 'Playoffs'], description='Season Type')
game_slider = widgets.IntSlider(min=0, description='Game ID')
event_slider = widgets.IntSlider(min=0, description='Event ID')

# Widgets to display game info and event info
game_info_text = widgets.Text(value="", description="Game Info", disabled=True, layout=widgets.Layout(width="90%"))
event_info_text = widgets.Text(value="", description="Event Info", disabled=True, layout=widgets.Layout(width="90%"))

# Widget to display the rink image
rink_image_output = widgets.Output()

# Function to plot event coordinates on the rink image
def plot_event_on_rink(x, y):
    rink_img_path = os.path.join('..','figures', 'nhl_rink.png')  # Update this to the correct path for the rink image
    rink_img = mpimg.imread(rink_img_path)

    with rink_image_output:
        rink_image_output.clear_output()  # Clear the previous plot
        fig, ax = plt.subplots(figsize=(6, 6))
        ax.imshow(rink_img, extent=[-100, 100, -42.5, 42.5])
        if x is not None and y is not None:
            ax.scatter(x, y, color='blue', label="Event location")
            ax.legend()
        plt.show()


# Function to format and return game information
def get_game_info(game_data):
    game_start_time = game_data.get("startTimeUTC", "Unknown Date")
    home_abbrev = game_data.get("homeTeam", {}).get("abbrev", "Unknown Home Abbrev")
    away_abbrev = game_data.get("awayTeam", {}).get("abbrev", "Unknown Away Abbrev")
    home_goals = game_data.get("homeTeam", {}).get("score", 0)
    away_goals = game_data.get("awayTeam", {}).get("score", 0)
    home_sog = game_data.get("homeTeam", {}).get("sog", 0)
    away_sog = game_data.get("awayTeam", {}).get("sog", 0)

    # Format the game state (period, overtime, etc.)
    game_period = game_data.get("periodDescriptor", {}).get("periodType", "Unknown")

    # Return formatted game info similar to the image
    return (f"{game_start_time}\n"
            f"Game ID: {game_data.get('id', 'Unknown')}; {home_abbrev} (home) vs {away_abbrev} (away)\n\n"
            f"{game_period}\n"
            f"          Home       Away\n"
            f"Teams:    {home_abbrev}         {away_abbrev}\n"
            f"Goals:    {home_goals}           {away_goals}\n"
            f"SoG:      {home_sog}           {away_sog}\n")


# Function to format and return event details
def get_event_info(event):
    # Use json.dumps to pretty-print the event data
    event_info_json = json.dumps(event, indent=4)

    # Return the formatted JSON string
    return event_info_json

# Download data based on season and season type
def on_season_or_type_change(change):
    global all_games
    selected_season = int(season.value)  # Get the selected season
    season_type_value = season_type.value

    # Download data based on season and type
    if season_type_value == 'Regular Season':
        all_games = downloader.download_regular_season(selected_season)
    else:
        all_games = downloader.download_playoffs(selected_season)

    # Ensure that all_games is not empty before proceeding
    if len(all_games) > 0:
        # Convert keys to a list and update the slider max value
        game_slider.max = len(all_games) - 1
        update_game_plot(0)
        update_event_plot(0, 0)

# Observe changes in season and season type dropdown
season.observe(on_season_or_type_change, names='value')
season_type.observe(on_season_or_type_change, names='value')

# Update plot based on game ID and event ID
def update_event_plot(game_index, event_index):
    global all_games
    global event_info_text

    # Get list of game IDs and access the selected game data
    game_ids = list(all_games.keys())
    if game_index < len(game_ids):
        game_id = game_ids[game_index]
        game_data = all_games.get(game_id, {})

        # Get the events for the selected game
        events = game_data.get("plays", [])
        if len(events) > 0 and event_index < len(events):
            event = events[event_index]
            x = event.get("details", {}).get("xCoord", None)
            y = event.get("details", {}).get("yCoord", None)
            if x is not None and y is not None:
                plot_event_on_rink(x, y)
            event_info_text.value = get_event_info(event)
        else:
            event_info_text.value = "No event data available."


# Update plot based on game ID and show game information
def update_game_plot(game_index):
    global all_games
    game_ids = list(all_games.keys())
    if game_index < len(game_ids):
        game_id = game_ids[game_index]
        game_data = all_games.get(game_id, {})
        clear_output()  # Clear the previous output to update new game info
        game_info_text.value = get_game_info(game_data)  # Update game info text
        event_slider.max = len(game_data.get("plays", [])) - 1  # Update event slider based on the number of events

def on_game_change(change):
    game_index = change['new']
    update_game_plot(game_index)
    update_event_plot(game_index, 0)

game_slider.observe(on_game_change, names='value')


# Update plot based on event ID
def on_event_change(change):
    game_index = game_slider.value
    event_index = change['new']
    update_event_plot(game_index, event_index)


event_slider.observe(on_event_change, names='value')

# Display widgets and text areas
display(season,season_type, game_slider, game_info_text, event_slider,rink_image_output, event_info_text)

# Initialize plot
update_event_plot(0, 0)
# Out:
# Dropdown(description='Season', options=('2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'), value…
# Dropdown(description='Season Type', options=('Regular Season', 'Playoffs'), value='Regular Season')
# IntSlider(value=0, description='Game ID')
# Text(value='', description='Game Info', disabled=True, layout=Layout(width='90%'))
# IntSlider(value=0, description='Event ID')
# Output()
# Text(value='', description='Event Info', disabled=True, layout=Layout(width='90%'))

# %% [markdown]
# 3. Data cleaning

# %%
game_id = "2016020002"
downloader = NHLDataDownloader()
shots_and_goals_df = downloader.extract_shots_and_goals_for_game(game_id)
print(shots_and_goals_df.head())
# Out:
# Game data for 2016020002 already exists in local cache.
#       game_id   game_date  period time_in_period    event_type  shot-on-goal  \
# 0  2016020002  2016-10-12       1          00:12  shot-on-goal          True
# 1  2016020002  2016-10-12       1          00:11           hit         False
# 2  2016020002  2016-10-12       1          01:10  shot-on-goal          True
# 3  2016020002  2016-10-12       1          01:24           hit         False
# 4  2016020002  2016-10-12       1          02:38           hit         False
#
#   shot_type  x_coord  y_coord  team_id   team_name team_type  empty_net  \
# 0      snap       64      -16       19       Blues      away      False
# 1   Unknown       88      -37       19       Blues      away      False
# 2     wrist       52       -8       19       Blues      away      False
# 3   Unknown      -95       21       16  Blackhawks      home      False
# 4   Unknown      -33      -37       16  Blackhawks      home      False
#
#   strength_status  shooter_id  goalie_id  shot_on_goal  hitting_player_id  \
# 0  Equal Strength   8470257.0  8470645.0          True                NaN
# 1  Equal Strength         NaN        NaN         False          8471669.0
# 2  Equal Strength   8474627.0  8470645.0          True                NaN
# 3  Equal Strength         NaN        NaN         False          8477353.0
# 4  Equal Strength         NaN        NaN         False          8479482.0
#
#    hittee_player_id
# 0               NaN
# 1         8470281.0
# 2               NaN
# 3         8476441.0
# 4         8476436.0
